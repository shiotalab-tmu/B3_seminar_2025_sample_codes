# %% [markdown]
# # 合成音声の生成
# - ここでは，目的話者の短い音声を参照として，その人の話者性を持つ任意の文章をの発話を生成する方法を概説します．
# - この技術はzero-shot voice cloningと呼ばれます．
# - ここでは，[CosyVoice](https://github.com/FunAudioLLM/CosyVoice/tree/main)というモデルを用いて合成音声を生成する方法を示します．
#
# ## 環境構築
# このノートブックを実行する前に、CosyVoice用の環境をセットアップしてください：

# %%
# !uv sync --extra cosyvoice
# Out:
# Resolved 222 packages in 38ms
# Audited 186 packages in 0.84ms

# %% [markdown]
# ## コードのダウンロード
# CosyVoiceのコードをクローンします．

# %%
# CosyVoiceをクローン
# !git clone --recursive https://github.com/FunAudioLLM/CosyVoice.git
# Out:
# Cloning into 'CosyVoice'...
# remote: Enumerating objects: 3025, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 3025 (delta 117), reused 75 (delta 75), pack-reused 2843 (from 3)
# Receiving objects: 100% (3025/3025), 2.07 MiB | 3.24 MiB/s, done.
# Resolving deltas: 100% (1755/1755), done.
# Submodule 'third_party/Matcha-TTS' (https://github.com/shivammehta25/Matcha-TTS.git) registered for path 'third_party/Matcha-TTS'
# Cloning into '/home/tenk9/ShiotaLab/B3_seminar_2025_sample_codes/handson/CosyVoice/third_party/Matcha-TTS'...
# remote: Enumerating objects: 1081, done.
# remote: Counting objects: 100% (556/556), done.
# remote: Compressing objects: 100% (201/201), done.
# remote: Total 1081 (delta 449), reused 355 (delta 355), pack-reused 525 (from 1)
# Receiving objects: 100% (1081/1081), 64.10 MiB | 7.28 MiB/s, done.
# Resolving deltas: 100% (538/538), done.
# Submodule path 'third_party/Matcha-TTS': checked out 'dd9105b34bf2be2230f4aa1e4769fb586a3c824e'

# %% [markdown]
# ## モデル本体をダウンロード

# %%
# !mkdir -p pretrained_models

# # Hugging Faceからモデルをダウンロード
# !git clone https://huggingface.co/FunAudioLLM/CosyVoice2-0.5B pretrained_models/CosyVoice2-0.5B

# modelscopeからDL
from modelscope import snapshot_download
snapshot_download('iic/CosyVoice2-0.5B', local_dir='pretrained_models/CosyVoice2-0.5B')
# Out:
# 2025-12-10 10:32:28,841 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# Downloading Model to directory: /home/tenk9/.cache/modelscope/hub/iic/CosyVoice2-0.5B
# 2025-12-10 10:32:29,095 DEBUG Incremented Retry for (url='/api/v1/models/iic/CosyVoice2-0.5B/revisions'): Retry(total=1, connect=2, read=1, redirect=None, status=None)
# 2025-12-10 10:32:29,097 WARNING Retrying (Retry(total=1, connect=2, read=1, redirect=None, status=None)) after connection broken by 'ConnectionResetError(104, 'Connection reset by peer')': /api/v1/models/iic/CosyVoice2-0.5B/revisions
# 2025-12-10 10:32:29,099 DEBUG Starting new HTTPS connection (2): www.modelscope.cn:443
# 2025-12-10 10:32:43,153 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/iic/CosyVoice2-0.5B/revisions HTTP/1.1" 200 None
# 2025-12-10 10:32:44,071 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/iic/CosyVoice2-0.5B/repo/files?Revision=master&Recursive=True HTTP/1.1" 200 None
# 2025-12-10 10:32:44,089 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# 2025-12-10 10:32:50,053 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.decoder.estimator.fp32.onnx HTTP/1.1" 200 286317026
# 2025-12-10 10:33:39,942 DEBUG Incremented Retry for (url='https://www.modelscope.cn/api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.decoder.estimator.fp32.onnx'): Retry(total=4, connect=None, read=None, redirect=None, status=None)
#
#
# Downloading [flow.decoder.estimator.fp32.onnx]:  94%|█████████▍| 258M/273M [00:55<00:03, 4.84MB/s]
# 2025-12-10 10:33:39,955 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# 2025-12-10 10:33:40,205 DEBUG Incremented Retry for (url='https://www.modelscope.cn/api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.decoder.estimator.fp32.onnx'): Retry(total=3, connect=None, read=None, redirect=None, status=None)
# Downloading [flow.decoder.estimator.fp32.onnx]:  94%|█████████▍| 258M/273M [00:02<00:00, 120MB/s]
# 2025-12-10 10:33:42,214 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# 2025-12-10 10:33:47,017 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.decoder.estimator.fp32.onnx HTTP/1.1" 200 15784418
# 2025-12-10 10:33:47,871 DEBUG Incremented Retry for (url='https://www.modelscope.cn/api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.decoder.estimator.fp32.onnx'): Retry(total=2, connect=None, read=None, redirect=None, status=None)
#
#
# Downloading [flow.decoder.estimator.fp32.onnx]:  94%|█████████▍| 258M/273M [00:09<00:00, 28.0MB/s]
# 2025-12-10 10:33:51,886 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# 2025-12-10 10:34:15,932 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.decoder.estimator.fp32.onnx HTTP/1.1" 200 15784418
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Downloading [flow.decoder.estimator.fp32.onnx]: 100%|██████████| 273M/273M [00:26<00:00, 10.8MB/s]
# 2025-12-10 10:34:19,112 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# 2025-12-10 10:34:20,452 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.encoder.fp16.zip HTTP/1.1" 200 116705475
# Downloading [flow.encoder.fp16.zip]: 100%|██████████| 111M/111M [00:16<00:00, 6.89MB/s]
# 2025-12-10 10:34:36,424 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# 2025-12-10 10:34:38,233 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.encoder.fp32.zip HTTP/1.1" 200 192367811
# 2025-12-10 10:34:41,627 DEBUG Incremented Retry for (url='https://www.modelscope.cn/api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.encoder.fp32.zip'): Retry(total=4, connect=None, read=None, redirect=None, status=None)
#
#
# Downloading [flow.encoder.fp32.zip]:   7%|▋         | 12.0M/183M [00:05<01:14, 2.41MB/s]
# 2025-12-10 10:34:41,651 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# 2025-12-10 10:35:03,677 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.encoder.fp32.zip HTTP/1.1" 200 179784899
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Downloading [flow.encoder.fp32.zip]: 100%|██████████| 183M/183M [00:42<00:00, 4.50MB/s]
# 2025-12-10 10:35:24,951 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# 2025-12-10 10:35:38,214 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.pt HTTP/1.1" 200 450575567
# 2025-12-10 10:35:38,866 DEBUG Incremented Retry for (url='https://www.modelscope.cn/api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.pt'): Retry(total=4, connect=None, read=None, redirect=None, status=None)
#
#
# Downloading [flow.pt]:   0%|          | 0.00/430M [00:13<?, ?B/s]
# 2025-12-10 10:35:38,907 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# 2025-12-10 10:35:41,090 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.pt HTTP/1.1" 200 450575567
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2025-12-10 10:35:51,396 DEBUG Incremented Retry for (url='https://www.modelscope.cn/api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.pt'): Retry(total=3, connect=None, read=None, redirect=None, status=None)
# Downloading [flow.pt]:  13%|█▎        | 58.0M/430M [00:14<01:32, 4.19MB/s]
# 2025-12-10 10:35:53,410 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# 2025-12-10 10:35:55,011 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.pt HTTP/1.1" 200 389758159
# 2025-12-10 10:36:29,147 DEBUG Incremented Retry for (url='https://www.modelscope.cn/api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.pt'): Retry(total=2, connect=None, read=None, redirect=None, status=None)
#
#
# Downloading [flow.pt]:  57%|█████▋    | 245M/430M [00:39<00:29, 6.46MB/s]
# 2025-12-10 10:36:33,161 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# 2025-12-10 10:36:36,523 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.pt HTTP/1.1" 200 193674447
#
#
#
#
#
#
#
#
#
#
# 2025-12-10 10:36:39,456 DEBUG Incremented Retry for (url='https://www.modelscope.cn/api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.pt'): Retry(total=1, connect=None, read=None, redirect=None, status=None)
# Downloading [flow.pt]:  61%|██████    | 260M/430M [00:14<00:09, 19.0MB/s]
# 2025-12-10 10:36:47,473 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# 2025-12-10 10:36:48,717 DEBUG https://www.modelscope.cn:443 "GET /api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.pt HTTP/1.1" 200 177945807
# 2025-12-10 10:36:49,775 DEBUG Incremented Retry for (url='https://www.modelscope.cn/api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.pt'): Retry(total=0, connect=None, read=None, redirect=None, status=None)
#
#
# Downloading [flow.pt]:  61%|██████    | 261M/430M [00:18<00:11, 14.9MB/s]
# 2025-12-10 10:37:05,787 DEBUG Starting new HTTPS connection (1): www.modelscope.cn:443
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/urllib3/connection.py:796, in HTTPSConnection.connect(self)
#     794 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 796 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     797     sock=sock,
#     798     cert_reqs=self.cert_reqs,
#     799     ssl_version=self.ssl_version,
#     800     ssl_minimum_version=self.ssl_minimum_version,
#     801     ssl_maximum_version=self.ssl_maximum_version,
#     802     ca_certs=self.ca_certs,
#     803     ca_cert_dir=self.ca_cert_dir,
#     804     ca_cert_data=self.ca_cert_data,
#     805     cert_file=self.cert_file,
#     806     key_file=self.key_file,
#     807     key_password=self.key_password,
#     808     server_hostname=server_hostname_rm_dot,
#     809     ssl_context=self.ssl_context,
#     810     tls_in_tls=tls_in_tls,
#     811     assert_hostname=self.assert_hostname,
#     812     assert_fingerprint=self.assert_fingerprint,
#     813 )
#     814 self.sock = sock_and_verified.socket
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/urllib3/connection.py:975, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     973         server_hostname = normalized
# --> 975 ssl_sock = ssl_wrap_socket(
#     976     sock=sock,
#     977     keyfile=key_file,
#     978     certfile=cert_file,
#     979     key_password=key_password,
#     980     ca_certs=ca_certs,
#     981     ca_cert_dir=ca_cert_dir,
#     982     ca_cert_data=ca_cert_data,
#     983     server_hostname=server_hostname,
#     984     ssl_context=context,
#     985     tls_in_tls=tls_in_tls,
#     986 )
#     988 try:
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/urllib3/util/ssl_.py:483, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     481 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 483 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     484 return ssl_sock
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/urllib3/util/ssl_.py:527, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     525     return SSLTransport(sock, ssl_context, server_hostname)
# --> 527 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File ~/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File ~/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/ssl.py:1104, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1103                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1104             self.do_handshake()
#    1105 except:
#
# File ~/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/ssl.py:1382, in SSLSocket.do_handshake(self, block)
#    1381         self.settimeout(None)
# -> 1382     self._sslobj.do_handshake()
#    1383 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.modelscope.cn'. (_ssl.c:1016)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# SSLError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.modelscope.cn'. (_ssl.c:1016)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.modelscope.cn', port=443): Max retries exceeded with url: /api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.pt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.modelscope.cn'. (_ssl.c:1016)")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/modelscope/hub/file_download.py:486, in http_get_model_file(url, local_dir, file_name, file_size, cookies, headers)
#     485 with open(temp_file_path, 'ab+') as f:
# --> 486     r = requests.get(
#     487         url,
#     488         stream=True,
#     489         headers=get_headers,
#     490         cookies=cookies,
#     491         timeout=API_FILE_DOWNLOAD_TIMEOUT)
#     492     r.raise_for_status()
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)     70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/requests/adapters.py:675, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     673 if isinstance(e.reason, _SSLError):
#     674     # This branch is for urllib3 v1.22 and later.
# --> 675     raise SSLError(e, request=request)
#     677 raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='www.modelscope.cn', port=443): Max retries exceeded with url: /api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.pt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.modelscope.cn'. (_ssl.c:1016)")))
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# Cell In[12], line 8
#       3 # # Hugging Faceからモデルをダウンロード
#       4 # !git clone https://huggingface.co/FunAudioLLM/CosyVoice2-0.5B pretrained_models/CosyVoice2-0.5B
#       5
#       6 # modelscopeからDL
#       7 from modelscope import snapshot_download
# ----> 8 snapshot_download('iic/CosyVoice2-0.5B', local_dir='pretrained_models/CosyVoice2-0.5B')
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/modelscope/hub/snapshot_download.py:85, in snapshot_download(model_id, revision, cache_dir, user_agent, local_files_only, cookies, ignore_file_pattern, allow_file_pattern, local_dir, allow_patterns, ignore_patterns)
#      27 def snapshot_download(
#      28     model_id: str,
#      29     revision: Optional[str] = DEFAULT_MODEL_REVISION,
#    (...)     38     ignore_patterns: Optional[Union[List[str], str]] = None,
#      39 ) -> str:
#      40     """Download all files of a repo.
#      41     Downloads a whole snapshot of a repo's files at the specified revision. This
#      42     is useful when you want all files from a repo, because you don't know which
#    (...)     83         if some parameter value is invalid
#      84     """
# ---> 85     return _snapshot_download(
#      86         model_id,
#      87         repo_type=REPO_TYPE_MODEL,
#      88         revision=revision,
#      89         cache_dir=cache_dir,
#      90         user_agent=user_agent,
#      91         local_files_only=local_files_only,
#      92         cookies=cookies,
#      93         ignore_file_pattern=ignore_file_pattern,
#      94         allow_file_pattern=allow_file_pattern,
#      95         local_dir=local_dir,
#      96         ignore_patterns=ignore_patterns,
#      97         allow_patterns=allow_patterns)
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/modelscope/hub/snapshot_download.py:247, in _snapshot_download(repo_id, repo_type, revision, cache_dir, user_agent, local_files_only, cookies, ignore_file_pattern, allow_file_pattern, local_dir, allow_patterns, ignore_patterns)
#     237     snapshot_header[
#     238         'cached_model_revision'] = cache.cached_model_revision
#     240 repo_files = _api.get_model_files(
#     241     model_id=repo_id,
#     242     revision=revision,
#    (...)    245     headers=snapshot_header,
#     246 )
# --> 247 _download_file_lists(
#     248     repo_files,
#     249     cache,
#     250     temporary_cache_dir,
#     251     repo_id,
#     252     _api,
#     253     None,
#     254     None,
#     255     headers,
#     256     repo_type=repo_type,
#     257     revision=revision,
#     258     cookies=cookies,
#     259     ignore_file_pattern=ignore_file_pattern,
#     260     allow_file_pattern=allow_file_pattern,
#     261     ignore_patterns=ignore_patterns,
#     262     allow_patterns=allow_patterns)
#     263 if '.' in repo_id:
#     264     masked_directory = get_model_masked_directory(
#     265         directory, repo_id)
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/modelscope/hub/snapshot_download.py:439, in _download_file_lists(repo_files, cache, temporary_cache_dir, repo_id, api, name, group_or_owner, headers, repo_type, revision, cookies, ignore_file_pattern, allow_file_pattern, allow_patterns, ignore_patterns)
#     434 else:
#     435     raise InvalidParameter(
#     436         f'Invalid repo type: {repo_type}, supported types: {REPO_TYPE_SUPPORT}'
#     437     )
# --> 439 download_file(url, repo_file, temporary_cache_dir, cache, headers,
#     440               cookies)
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/modelscope/hub/file_download.py:601, in download_file(url, file_meta, temporary_cache_dir, cache, headers, cookies)
#     593     parallel_download(
#     594         url,
#     595         temporary_cache_dir,
#    (...)    598         cookies=None if cookies is None else cookies.get_dict(),
#     599         file_size=file_meta['Size'])
#     600 else:
# --> 601     http_get_model_file(
#     602         url,
#     603         temporary_cache_dir,
#     604         file_meta['Path'],
#     605         file_size=file_meta['Size'],
#     606         headers=headers,
#     607         cookies=cookies)
#     609 # check file integrity
#     610 temp_file = os.path.join(temporary_cache_dir, file_meta['Path'])
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/modelscope/hub/file_download.py:501, in http_get_model_file(url, local_dir, file_name, file_size, cookies, headers)
#     499         break
#     500     except (Exception) as e:  # no matter what happen, we will retry.
# --> 501         retry = retry.increment('GET', url, error=e)
#     502         retry.sleep()
#     504 logger.debug('storing %s in cache at %s', url, local_dir)
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     517 if new_retry.is_exhausted():
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#     523 return new_retry
#
# MaxRetryError: None: Max retries exceeded with url: https://www.modelscope.cn/api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.pt (Caused by SSLError(MaxRetryError('HTTPSConnectionPool(host=\'www.modelscope.cn\', port=443): Max retries exceeded with url: /api/v1/models/iic/CosyVoice2-0.5B/repo?Revision=master&FilePath=flow.pt (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for \'www.modelscope.cn\'. (_ssl.c:1016)")))')))
# Downloading [campplus.onnx]:  56%|█████▌    | 15.0M/27.0M [45:18<36:13, 5.79kB/s]
# Downloading [flow.decoder.estimator.fp32.onnx]:   0%|          | 0.00/273M [05:16<?, ?B/s]

# %% [markdown]
# ## 実行

# %% [markdown]
# Qwen2ForCausalLMが見つからないと言われたり，何もしていないのにエラーが出たときは，ipynbのカーネルを再起動してみてください．
# 一応重いけどCPUでも動くはず．

# %%
import sys

sys.path.append("CosyVoice")
sys.path.append("CosyVoice/third_party/Matcha-TTS")
from cosyvoice.cli.cosyvoice import CosyVoice, CosyVoice2
from cosyvoice.utils.file_utils import load_wav
import torchaudio
import os

# modelのインスタンス化
cosyvoice = CosyVoice2(
    "pretrained_models/CosyVoice2-0.5B",
    load_jit=False,
    load_trt=False,
    load_vllm=False,
    fp16=False,
)

# 参照音声を読み込み
prompt_speech_16k = load_wav("./audiofile/ymgt.wav", 16000)

# 合成音声を生成
## 読み上げ文章，発話スタイル等のプロンプトをそれぞれ指定
## うまく出力されないときはこれらを調整する．
## 本来はendofpromptとか入れなくても動くらしいが，入れたほうが安定するので入れています．
## 参考：公式Usage：https://github.com/FunAudioLLM/CosyVoice/blob/main/README.md
## 参考：特殊トークン: https://github.com/FunAudioLLM/CosyVoice/blob/main/cosyvoice/tokenizer/tokenizer.py
reading_texts = [
    "<|jp|> [breath] みなみおおさわキャンパスの法定停電に伴い、 [clucking] 以下の期間はキャンパススクエア・自動証明書発行機を利用できません。 <|endoftext|>",
    "<|en|> An extremely fast Python package and project manager, written in Rust. <|endoftext|>",
]
prompt = "<|jp|> 流暢で早口な，元気な読み上げ音声 <|endofprompt|>"

out_dir = "./CosyVoice_output"
os.makedirs(out_dir, exist_ok=True)

for i, txt in enumerate(reading_texts):
    # outputは一つだけだが，返り値のType的にforで拾ってやる必要がある（他にもやり方はあるが公式Usageに則る）
    for output in cosyvoice.inference_zero_shot(
        txt,
        prompt,
        prompt_speech_16k,
        stream=False,
        text_frontend=False,
    ):
        cloned_speech = output["tts_speech"]

        # 音声を保存
        torchaudio.save(
            f"{out_dir}/out{i}.wav",
            src=cloned_speech,
            sample_rate=cosyvoice.sample_rate,
        )
# Out:
# ---------------------------------------------------------------------------
# SafetensorError                           Traceback (most recent call last)
# Cell In[9], line 11
#       8 import os
#      10 # modelのインスタンス化
# ---> 11 cosyvoice = CosyVoice2(
#      12     "pretrained_models/CosyVoice2-0.5B",
#      13     load_jit=False,
#      14     load_trt=False,
#      15     load_vllm=False,
#      16     fp16=False,
#      17 )
#      19 # 参照音声を読み込み
#      20 prompt_speech_16k = load_wav("./audiofile/ymgt.wav", 16000)
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/handson/CosyVoice/cosyvoice/cli/cosyvoice.py:154, in CosyVoice2.__init__(self, model_dir, load_jit, load_trt, load_vllm, fp16, trt_concurrent)
#     152     raise ValueError('{} not found!'.format(hyper_yaml_path))
#     153 with open(hyper_yaml_path, 'r') as f:
# --> 154     configs = load_hyperpyyaml(f, overrides={'qwen_pretrain_path': os.path.join(model_dir, 'CosyVoice-BlankEN')})
#     155 assert get_model_type(configs) == CosyVoice2Model, 'do not use {} for CosyVoice2 initialization!'.format(model_dir)
#     156 self.frontend = CosyVoiceFrontEnd(configs['get_tokenizer'],
#     157                                   configs['feat_extractor'],
#     158                                   '{}/campplus.onnx'.format(model_dir),
#     159                                   '{}/speech_tokenizer_v2.onnx'.format(model_dir),
#     160                                   '{}/spk2info.pt'.format(model_dir),
#     161                                   configs['allowed_special'])
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/hyperpyyaml/core.py:188, in load_hyperpyyaml(yaml_stream, overrides, overrides_must_match, loader)
#     182 yaml.constructor.BaseConstructor.construct_object.__defaults__ = (
#     183     True,
#     184 )  # deep=True
#     185 ruamel.yaml.constructor.BaseConstructor.construct_object.__defaults__ = (
#     186     True,
#     187 )  # deep=True
# --> 188 hparams = yaml.load(yaml_stream, Loader=loader)
#     189 # Change back to normal default:
#     190 yaml.constructor.BaseConstructor.construct_object.__defaults__ = (
#     191     False,
#     192 )  # deep=False
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/yaml/__init__.py:81, in load(stream, Loader)
#      79 loader = Loader(stream)
#      80 try:
# ---> 81     return loader.get_single_data()
#      82 finally:
#      83     loader.dispose()
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/ruamel/yaml/constructor.py:119, in BaseConstructor.get_single_data(self)
#     117 node = self.composer.get_single_node()
#     118 if node is not None:
# --> 119     return self.construct_document(node)
#     120 return None
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/ruamel/yaml/constructor.py:123, in BaseConstructor.construct_document(self, node)
#     122 def construct_document(self, node: Any) -> Any:
# --> 123     data = self.construct_object(node)
#     124     while bool(self.state_generators):
#     125         state_generators = self.state_generators
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/ruamel/yaml/constructor.py:150, in BaseConstructor.construct_object(self, node, deep)
#     146     # raise ConstructorError(
#     147     #     None, None, 'found unconstructable recursive node', node.start_mark
#     148     # )
#     149 self.recursive_objects[node] = None
# --> 150 data = self.construct_non_recursive_object(node)
#     152 self.constructed_objects[node] = data
#     153 del self.recursive_objects[node]
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/ruamel/yaml/constructor.py:191, in BaseConstructor.construct_non_recursive_object(self, node, tag)
#     189 data = next(generator)
#     190 if self.deep_construct:
# --> 191     for _dummy in generator:
#     192         pass
#     193 else:
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/ruamel/yaml/constructor.py:629, in SafeConstructor.construct_yaml_map(self, node)
#     627 data: Dict[Any, Any] = self.yaml_base_dict_type()
#     628 yield data
# --> 629 value = self.construct_mapping(node)
#     630 data.update(value)
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/ruamel/yaml/constructor.py:425, in SafeConstructor.construct_mapping(self, node, deep)
#     423 if isinstance(node, MappingNode):
#     424     self.flatten_mapping(node)
# --> 425 return BaseConstructor.construct_mapping(self, node, deep=deep)
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/ruamel/yaml/constructor.py:247, in BaseConstructor.construct_mapping(self, node, deep)
#     239 if not isinstance(key, Hashable):
#     240     raise ConstructorError(
#     241         'while constructing a mapping',
#     242         node.start_mark,
#     243         'found unhashable key',
#     244         key_node.start_mark,
#     245     )
# --> 247 value = self.construct_object(value_node, deep=deep)
#     248 if check:
#     249     if self.check_mapping_key(node, key_node, mapping, key, value):
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/ruamel/yaml/constructor.py:150, in BaseConstructor.construct_object(self, node, deep)
#     146     # raise ConstructorError(
#     147     #     None, None, 'found unconstructable recursive node', node.start_mark
#     148     # )
#     149 self.recursive_objects[node] = None
# --> 150 data = self.construct_non_recursive_object(node)
#     152 self.constructed_objects[node] = data
#     153 del self.recursive_objects[node]
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/ruamel/yaml/constructor.py:186, in BaseConstructor.construct_non_recursive_object(self, node, tag)
#     184     data = constructor(self, node)
#     185 else:
# --> 186     data = constructor(self, tag_suffix, node)
#     187 if isinstance(data, types.GeneratorType):
#     188     generator = data
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/hyperpyyaml/core.py:480, in _construct_object(loader, callable_string, node)
#     475     raise ValueError(
#     476         f"!new:{callable_string} should be a class, but is {callable_}"
#     477     )
#     479 try:
# --> 480     args, kwargs = _load_node(loader, node)
#     481     return callable_(*args, **kwargs)
#     482 except TypeError as e:
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/hyperpyyaml/core.py:434, in _load_node(loader, node)
#     429 def _load_node(loader, node):
#     430     if (
#     431             isinstance(node, yaml.MappingNode) or
#     432             isinstance(node, ruamel.yaml.MappingNode)
#     433     ):
# --> 434         kwargs = loader.construct_mapping(node, deep=True)
#     435         return [], kwargs
#     436     elif (
#     437             isinstance(node, yaml.SequenceNode) or
#     438             isinstance(node, ruamel.yaml.SequenceNode)
#     439     ):
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/ruamel/yaml/constructor.py:425, in SafeConstructor.construct_mapping(self, node, deep)
#     423 if isinstance(node, MappingNode):
#     424     self.flatten_mapping(node)
# --> 425 return BaseConstructor.construct_mapping(self, node, deep=deep)
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/ruamel/yaml/constructor.py:247, in BaseConstructor.construct_mapping(self, node, deep)
#     239 if not isinstance(key, Hashable):
#     240     raise ConstructorError(
#     241         'while constructing a mapping',
#     242         node.start_mark,
#     243         'found unhashable key',
#     244         key_node.start_mark,
#     245     )
# --> 247 value = self.construct_object(value_node, deep=deep)
#     248 if check:
#     249     if self.check_mapping_key(node, key_node, mapping, key, value):
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/ruamel/yaml/constructor.py:150, in BaseConstructor.construct_object(self, node, deep)
#     146     # raise ConstructorError(
#     147     #     None, None, 'found unconstructable recursive node', node.start_mark
#     148     # )
#     149 self.recursive_objects[node] = None
# --> 150 data = self.construct_non_recursive_object(node)
#     152 self.constructed_objects[node] = data
#     153 del self.recursive_objects[node]
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/ruamel/yaml/constructor.py:186, in BaseConstructor.construct_non_recursive_object(self, node, tag)
#     184     data = constructor(self, node)
#     185 else:
# --> 186     data = constructor(self, tag_suffix, node)
#     187 if isinstance(data, types.GeneratorType):
#     188     generator = data
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/hyperpyyaml/core.py:481, in _construct_object(loader, callable_string, node)
#     479 try:
#     480     args, kwargs = _load_node(loader, node)
# --> 481     return callable_(*args, **kwargs)
#     482 except TypeError as e:
#     483     err_msg = "Invalid argument to class %s" % callable_string
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/handson/CosyVoice/cosyvoice/llm/llm.py:234, in Qwen2Encoder.__init__(self, pretrain_path)
#     232 def __init__(self, pretrain_path):
#     233     super().__init__()
# --> 234     self.model = Qwen2ForCausalLM.from_pretrained(pretrain_path)
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/transformers/modeling_utils.py:279, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     277 old_dtype = torch.get_default_dtype()
#     278 try:
# --> 279     return func(*args, **kwargs)
#     280 finally:
#     281     torch.set_default_dtype(old_dtype)
#
# File ~/ShiotaLab/B3_seminar_2025_sample_codes/.venv/lib/python3.11/site-packages/transformers/modeling_utils.py:4288, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4280 is_from_file = pretrained_model_name_or_path is not None or gguf_file is not None
#    4282 if (
#    4283     is_safetensors_available()
#    4284     and is_from_file
#    4285     and not is_sharded
#    4286     and checkpoint_files[0].endswith(".safetensors")
#    4287 ):
# -> 4288     with safe_open(checkpoint_files[0], framework="pt") as f:
#    4289         metadata = f.metadata()
#    4291     if metadata is None:
#    4292         # Assume it's a pytorch checkpoint (introduced for timm checkpoints)
#
# SafetensorError: Error while deserializing header: header too large

# %% [markdown]
# ## 音声の確認

# %%
import IPython.display as ipd

# 参照音声を再生
print("参照音声:")
display(ipd.Audio("./audiofile/ymgt.wav"))

# 生成された音声を再生
print("\n生成された音声1 (日本語):")
display(ipd.Audio(f"{out_dir}/out0.wav"))

print("\n生成された音声2 (英語):")
display(ipd.Audio(f"{out_dir}/out1.wav"))
# Out:
# 参照音声:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 生成された音声1 (日本語):
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 生成された音声2 (英語):
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
